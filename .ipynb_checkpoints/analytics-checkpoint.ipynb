# %% [markdown]
# # Analytics

# %% [markdown]
# #### Date: 2020/05
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.

# %% [markdown]
# ### TEAM:
#
# ##### Semester: 2020/02
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - André Pinto

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import numpy as np
import json
from glob import glob
import os

# Deal with API request
import urllib3
from urllib3 import request

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### SonarCloud

# %% [markdown]
# ##### repo names, lenguage and path to the folder with all your jsons

# %%
#insert the repo names and used lenguages

repos = ['2020_2-Projeto-Kokama-Traducao', 
         '2020_2-Projeto-Kokama-Usuario', 
         '2020_2-Projeto-Kokama-Ensino', 
         '2020_2-Projeto-Kokama-Front-end']
language = [['2020_2-Projeto-Kokama-Traducao', 'py'], 
            ['2020_2-Projeto-Kokama-Usuario', 'py'], 
            ['2020_2-Projeto-Kokama-Ensino', 'py'], 
            ['2020_2-Projeto-Kokama-Front-end', 'ts']]

repos_lenguage = {}

for item in language:
    repos_lenguage[f"{item[0]}"] = item[1]

# %%
repos_lenguage
# Out:
# {'2020_2-Projeto-Kokama-Traducao': 'py',
#  '2020_2-Projeto-Kokama-Usuario': 'py',
#  '2020_2-Projeto-Kokama-Ensino': 'py',
#  '2020_2-Projeto-Kokama-Front-end': 'ts'}

# %%
jsons = glob('analytics-raw-data/*.json') # add the path here

# %%
def read_json(json_path):
    
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
        
    return json_obj

def create_base_component_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        base_component = read_json(i)

        base_component_data = base_component['baseComponent']['measures']

        base_component_df = pd.DataFrame(base_component_data)

        base_component_df['filename'] = os.path.basename(i)

        df = df.append(base_component_df, ignore_index=True)
        
    aux_df = df['filename'].str.split(r"fga-eps-mds-(.*?)-(\d+-\d+-\d+).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[2]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df, repos

# %% [markdown]
# #### Create base component dataframe and repos list

# %%
base_component_df, repos = create_base_component_df(jsons)

# %%
base_component_df.head(10)
# Out:
#                       metric value bestValue  \
# 88                complexity    37       NaN
# 89  duplicated_lines_density   0.0      True
# 90                 functions    15       NaN
# 91                     ncloc   726       NaN
# 92        reliability_rating   1.0      True
# 93           security_rating   1.0      True
# 94     comment_lines_density   7.8     False
# 95                     files    30       NaN
# 32  duplicated_lines_density   0.0      True
# 33                 functions    15       NaN
#
#                                              filename  \
# 88  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 89  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 90  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 91  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 92  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 93  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 94  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 95  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 32  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-05...
# 33  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-05...
#
#                       repository     version
# 88  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 89  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 90  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 91  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 92  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 93  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 94  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 95  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 32  2020_2-Projeto-Kokama-Ensino  14-05-2021
# 33  2020_2-Projeto-Kokama-Ensino  14-05-2021

# %% [markdown]
# #### Create dataframe per file

# %%
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'coverage',
               'ncloc',
               'security_rating',
               'tests',
               'test_success_density',
               'test_execution_time',
               'reliability_rating']

len(metric_list)
# Out:
# 12

# %%
def metric_per_file(json):
    
    file_json = []
    
    for component in json['components']:
        if component['qualifier'] == 'FIL':
            file_json.append(component)
            
    return file_json

# %%
def generate_file_dataframe_per_release(metric_list, json, language_extension):
    
    df_columns = metric_list
    df = pd.DataFrame(columns = df_columns)
    
    for file in json:
        try:
            if file['language'] == language_extension:
                for measure in file['measures']:
                    df.at[file['path'], measure['metric']] = measure['value']
        except:
            pass
        
    df.reset_index(inplace = True)
    df = df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    return df

# %%
def create_file_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        file_component = read_json(i)
        file_component_data = metric_per_file(file_component)
        file_name = os.path.basename(i)
               
        file_repository = file_name[12:-16]
        file_lenguage = repos_lenguage[f"{file_repository}"]
        
        file_component_df = generate_file_dataframe_per_release(metric_list, 
                                                                file_component_data,
                                                                language_extension = file_lenguage)
        file_component_df['filename'] = file_name

        df = df.append(file_component_df, ignore_index=True)
        
    # replace TeamName by yours.   
    aux_df = df['filename'].str.split(r"fga-eps-mds-(.*?)-(\d+-\d+-\d+).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[2]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df

# %%
file_component_df = create_file_df(jsons)

# %%
file_component_df.head(10)
# Out:
#                           path functions complexity comment_lines_density  \
# 227       exercise/__init__.py         0          0                   NaN
# 228        history/__init__.py         0          0                   NaN
# 229          tests/__init__.py         0          0                   NaN
# 230  tests/history/__init__.py         0          0                   0.0
# 231          exercise/admin.py         0          0                   0.0
# 232           history/admin.py         0          0                   0.0
# 233           exercise/apps.py         0          0                   0.0
# 234            history/apps.py         0          0                   0.0
# 235              learn/asgi.py         0          0                  66.7
# 236           history/forms.py         0          0                   0.0
#
#     duplicated_lines_density coverage ncloc security_rating tests  \
# 227                      0.0      NaN     0             1.0   NaN
# 228                      0.0      NaN     0             1.0   NaN
# 229                      0.0      NaN     0             1.0   NaN
# 230                      0.0      NaN     1             1.0   NaN
# 231                      0.0      NaN     5             1.0   NaN
# 232                      0.0      NaN     3             1.0   NaN
# 233                      0.0      NaN     3             1.0   NaN
# 234                      0.0      NaN     3             1.0   NaN
# 235                      0.0      NaN     4             1.0   NaN
# 236                      0.0      NaN    13             1.0   NaN
#
#     test_success_density test_execution_time reliability_rating  \
# 227                100.0                 NaN                1.0
# 228                100.0                 NaN                1.0
# 229                100.0                 NaN                1.0
# 230                100.0                 NaN                1.0
# 231                100.0                 NaN                1.0
# 232                100.0                 NaN                1.0
# 233                100.0                 NaN                1.0
# 234                100.0                 NaN                1.0
# 235                100.0                 NaN                1.0
# 236                100.0                 NaN                1.0
#
#                                               filename  \
# 227  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 228  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 229  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 230  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 231  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 232  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 233  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 234  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 235  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
# 236  fga-eps-mds-2020_2-Projeto-Kokama-Ensino-14-04...
#
#                        repository     version
# 227  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 228  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 229  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 230  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 231  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 232  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 233  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 234  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 235  2020_2-Projeto-Kokama-Ensino  14-04-2021
# 236  2020_2-Projeto-Kokama-Ensino  14-04-2021

# %%
file_component_df.to_excel('data/data.xlsx', index = False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-85083c3a7248> in <module>
# ----> 1 file_component_df.to_excel('data/data.xlsx', index = False)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# ~/.local/lib/python3.8/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     813             # abstract class 'ExcelWriter' with abstract attributes 'engine',
#     814             # 'save', 'supported_extensions' and 'write_cells'  [abstract]
# --> 815             writer = ExcelWriter(  # type: ignore[abstract]
#     816                 writer, engine=engine, storage_options=storage_options
#     817             )
#
# ~/.local/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, mode, storage_options, **engine_kwargs)
#      28     ):
#      29         # Use the openpyxl module as the Excel writer.
# ---> 30         from openpyxl.workbook import Workbook
#      31
#      32         super().__init__(
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
file_component_df.repository.unique()
# Out:
# array(['2020_2-Projeto-Kokama-Ensino', '2020_2-Projeto-Kokama-Front-end',
#        '2020_2-Projeto-Kokama-Traducao', '2020_2-Projeto-Kokama-Usuario'],
#       dtype=object)

# %% [markdown]
# #### Create dataframe per repository

# %%
repository_dataframes = {} 

for repository in repos:
    df = file_component_df[file_component_df['repository'] == f"{repository}"]
    df.name = f"{repository}"
    repository_dataframes[f"{repository}"] = df
    
repository_dataframes.keys()
# Out:
# dict_keys(['2020_2-Projeto-Kokama-Traducao', '2020_2-Projeto-Kokama-Usuario', '2020_2-Projeto-Kokama-Ensino', '2020_2-Projeto-Kokama-Front-end'])

# %%
repository_dataframes["2020_2-Projeto-Kokama-Front-end"]
# Out:
#                                                   path functions complexity  \
# 6                        projeto-kokama/src/api/Api.ts         0          0
# 7                               projeto-kokama/App.tsx         9          9
# 8                  projeto-kokama/src/assets/Colors.ts         0          0
# 9               projeto-kokama/src/config/constants.ts         0          0
# 10              projeto-kokama/src/utils/dictionary.ts         4          9
# 11           projeto-kokama/src/components/History.tsx         3          5
# 12      projeto-kokama/src/components/HistoryTitle.tsx         1          4
# 13                        projeto-kokama/src/index.tsx         1          1
# 14    projeto-kokama/src/screens/Translation/index.tsx        21         42
# 15   projeto-kokama/src/screens/KokamaStories/index...         3          4
# 16          projeto-kokama/src/screens/Story/index.tsx         1          1
# 17       projeto-kokama/src/screens/Learning/index.tsx         2          2
# 18   projeto-kokama/src/screens/Translation/interfa...         0          0
# 19   projeto-kokama/src/screens/KokamaStories/inter...         0          0
# 20           projeto-kokama/src/components/Stories.tsx         3          3
# 21    projeto-kokama/src/screens/Translation/styles.ts         0          1
# 22   projeto-kokama/src/screens/KokamaStories/style...         0          0
# 23          projeto-kokama/src/screens/Story/styles.ts         0          0
# 24       projeto-kokama/src/screens/Learning/styles.ts         0          0
# 25           projeto-kokama/src/components/TopMenu.tsx         1          2
# 26             projeto-kokama/src/utils/translation.ts         2          2
# 27                   projeto-kokama/src/config/urls.ts         0          0
# 101                      projeto-kokama/src/api/Api.ts         0          0
# 102                             projeto-kokama/App.tsx        12         12
# 103                projeto-kokama/src/assets/Colors.ts         0          0
# 104             projeto-kokama/src/config/constants.ts         0          0
# 105             projeto-kokama/src/utils/dictionary.ts         4          9
# 106          projeto-kokama/src/components/History.tsx         3          5
# 107     projeto-kokama/src/components/HistoryTitle.tsx         1          4
# 108                       projeto-kokama/src/index.tsx         1          1
# 109   projeto-kokama/src/screens/Translation/index.tsx        21         42
# 110  projeto-kokama/src/screens/KokamaStories/index...         5          8
# 111         projeto-kokama/src/screens/Story/index.tsx         1          1
# 112      projeto-kokama/src/screens/Learning/index.tsx         2          2
# 113         projeto-kokama/src/screens/About/index.tsx         1          1
# 114  projeto-kokama/src/screens/Translation/interfa...         0          0
# 115  projeto-kokama/src/screens/KokamaStories/inter...         0          0
# 116   projeto-kokama/src/components/SpinnerLoading.tsx         1          1
# 117   projeto-kokama/src/screens/Translation/styles.ts         0          1
# 118  projeto-kokama/src/screens/KokamaStories/style...         0          0
# 119         projeto-kokama/src/screens/Story/styles.ts         0          0
# 120      projeto-kokama/src/screens/Learning/styles.ts         0          0
# 121         projeto-kokama/src/screens/About/styles.ts         0          0
# 122          projeto-kokama/src/components/TopMenu.tsx         1          2
# 123       projeto-kokama/src/utils/translation.test.ts         1          1
# 124            projeto-kokama/src/utils/translation.ts         2          2
# 125                  projeto-kokama/src/config/urls.ts         0          0
# 68                projeto-kokama/src/utils/activity.ts         1          5
# 69                       projeto-kokama/src/api/Api.ts         0          0
# 70                              projeto-kokama/App.tsx        13         13
# 71                 projeto-kokama/src/assets/Colors.ts         0          0
# 72              projeto-kokama/src/config/constants.ts         0          0
# 73              projeto-kokama/src/utils/dictionary.ts         4          9
# 74           projeto-kokama/src/components/History.tsx         3          5
# 75      projeto-kokama/src/components/HistoryTitle.tsx         1          4
# 76                        projeto-kokama/src/index.tsx         1          1
# 77    projeto-kokama/src/screens/Translation/index.tsx        21         42
# 78   projeto-kokama/src/screens/KokamaStories/index...         5          8
# 79          projeto-kokama/src/screens/Story/index.tsx         1          1
# 80       projeto-kokama/src/screens/Learning/index.tsx         3          3
# 81          projeto-kokama/src/screens/About/index.tsx         3          3
# 82       projeto-kokama/src/screens/Activity/index.tsx        19         33
# 83   projeto-kokama/src/components/MemberPhoto/inde...         2          3
# 84   projeto-kokama/src/screens/Translation/interfa...         0          0
# 85   projeto-kokama/src/screens/KokamaStories/inter...         0          0
# 86    projeto-kokama/src/screens/Activity/interface.ts         0          0
# 87   projeto-kokama/src/components/MemberPhoto/inte...         0          0
# 88     projeto-kokama/src/screens/About/membersData.ts         0          0
# 89    projeto-kokama/src/components/SpinnerLoading.tsx         1          1
# 90    projeto-kokama/src/screens/Translation/styles.ts         0          1
# 91   projeto-kokama/src/screens/KokamaStories/style...         0          0
# 92          projeto-kokama/src/screens/Story/styles.ts         0          0
# 93       projeto-kokama/src/screens/Learning/styles.ts         0          0
# 94          projeto-kokama/src/screens/About/styles.ts         0          0
# 95       projeto-kokama/src/screens/Activity/styles.ts         0          0
# 96   projeto-kokama/src/components/MemberPhoto/styl...         0          0
# 97           projeto-kokama/src/components/TopMenu.tsx         1          2
# 98        projeto-kokama/src/utils/translation.test.ts         1          1
# 99             projeto-kokama/src/utils/translation.ts         2          2
# 100                  projeto-kokama/src/config/urls.ts         0          0
# 0                               projeto-kokama/App.tsx         1          1
# 1               projeto-kokama/src/config/constants.ts         0          0
# 2                         projeto-kokama/src/index.tsx         1          1
# 3     projeto-kokama/src/screens/Translation/index.tsx        18         37
# 4    projeto-kokama/src/screens/Translation/interfa...         0          0
# 5     projeto-kokama/src/screens/Translation/styles.ts         0          1
#
#     comment_lines_density duplicated_lines_density coverage ncloc  \
# 6                     0.0                      0.0      NaN     5
# 7                     4.9                      0.0      NaN    98
# 8                     0.0                      0.0      NaN    11
# 9                     0.0                      0.0      NaN     3
# 10                    0.0                      0.0      NaN    38
# 11                    0.0                      0.0      NaN    70
# 12                    0.0                      0.0      NaN    55
# 13                    0.0                      0.0      NaN    16
# 14                   10.1                      0.0      NaN   286
# 15                    0.0                      0.0      NaN    39
# 16                    0.0                      0.0      NaN    22
# 17                    0.0                      0.0      NaN    24
# 18                    0.0                      0.0      NaN    14
# 19                    0.0                      0.0      NaN     5
# 20                    2.1                      0.0      NaN    47
# 21                    0.6                      0.0      NaN   175
# 22                    1.5                      0.0      NaN    65
# 23                    4.0                      0.0      NaN    24
# 24                    4.3                      0.0      NaN    22
# 25                    0.0                      0.0      NaN    42
# 26                    0.0                      0.0      NaN     8
# 27                    0.0                      0.0      NaN     2
# 101                   0.0                      0.0      NaN     5
# 102                   4.6                      0.0      NaN   124
# 103                   0.0                      0.0      NaN    11
# 104                   0.0                      0.0      NaN     3
# 105                   0.0                      0.0      NaN    38
# 106                   0.0                      0.0      NaN    70
# 107                   0.0                      0.0      NaN    55
# 108                   0.0                      0.0      NaN    16
# 109                  10.1                      0.0      NaN   286
# 110                   0.0                      0.0      NaN    51
# 111                   0.0                      0.0      NaN    25
# 112                   0.0                      0.0      NaN    25
# 113                   0.0                      0.0      NaN    29
# 114                   0.0                      0.0      NaN    14
# 115                   0.0                      0.0      NaN     5
# 116                   0.0                      0.0      NaN    28
# 117                   0.6                      0.0      NaN   175
# 118                   1.5                      0.0      NaN    65
# 119                   4.0                      0.0      NaN    24
# 120                   4.3                      0.0      NaN    22
# 121                   6.1                      0.0      NaN    31
# 122                   0.0                      0.0      NaN    42
# 123                   0.0                      0.0      NaN     6
# 124                   0.0                      0.0      NaN     8
# 125                   0.0                      0.0      NaN     2
# 68                    0.0                      0.0      NaN    23
# 69                    0.0                      0.0      NaN     5
# 70                    4.7                      0.0      NaN   143
# 71                    0.0                      0.0      NaN    12
# 72                    0.0                      0.0      NaN     3
# 73                    0.0                      0.0      NaN    38
# 74                    0.0                      0.0      NaN    70
# 75                    0.0                      0.0      NaN    55
# 76                    0.0                      0.0      NaN    16
# 77                   10.1                      0.0      NaN   286
# 78                    0.0                      0.0      NaN    51
# 79                    0.0                      0.0      NaN    25
# 80                    0.0                      0.0      NaN    30
# 81                    0.0                      0.0      NaN    44
# 82                    0.0                      0.0      NaN   254
# 83                    0.0                      0.0      NaN    15
# 84                    0.0                      0.0      NaN    14
# 85                    0.0                      0.0      NaN     5
# 86                    0.0                      0.0      NaN     6
# 87                    0.0                      0.0      NaN     4
# 88                    0.0                      0.0      NaN    24
# 89                    0.0                      0.0      NaN    28
# 90                    0.6                      0.0      NaN   175
# 91                    1.5                      0.0      NaN    65
# 92                    4.0                      0.0      NaN    24
# 93                    4.2                      0.0      NaN    23
# 94                    0.0                      0.0      NaN    30
# 95                    1.2                      0.0      NaN    83
# 96                    0.0                      0.0      NaN    18
# 97                    0.0                      0.0      NaN    42
# 98                    0.0                      0.0      NaN     6
# 99                    0.0                      0.0      NaN     8
# 100                   0.0                      0.0      NaN     2
# 0                     0.0                      0.0      NaN     8
# 1                     0.0                      0.0      NaN     2
# 2                     0.0                      0.0      NaN     8
# 3                     3.4                      0.0      NaN   225
# 4                     0.0                      0.0      NaN    10
# 5                     0.6                      0.0      NaN   176
#
#     security_rating tests test_success_density test_execution_time  \
# 6               1.0   NaN                100.0                 NaN
# 7               1.0   NaN                100.0                 NaN
# 8               1.0   NaN                100.0                 NaN
# 9               1.0   NaN                100.0                 NaN
# 10              1.0   NaN                100.0                 NaN
# 11              1.0   NaN                100.0                 NaN
# 12              1.0   NaN                100.0                 NaN
# 13              1.0   NaN                100.0                 NaN
# 14              1.0   NaN                100.0                 NaN
# 15              1.0   NaN                100.0                 NaN
# 16              1.0   NaN                100.0                 NaN
# 17              1.0   NaN                100.0                 NaN
# 18              1.0   NaN                100.0                 NaN
# 19              1.0   NaN                100.0                 NaN
# 20              1.0   NaN                100.0                 NaN
# 21              1.0   NaN                100.0                 NaN
# 22              1.0   NaN                100.0                 NaN
# 23              1.0   NaN                100.0                 NaN
# 24              1.0   NaN                100.0                 NaN
# 25              1.0   NaN                100.0                 NaN
# 26              1.0   NaN                100.0                 NaN
# 27              1.0   NaN                100.0                 NaN
# 101             1.0   NaN                100.0                 NaN
# 102             1.0   NaN                100.0                 NaN
# 103             1.0   NaN                100.0                 NaN
# 104             1.0   NaN                100.0                 NaN
# 105             1.0   NaN                100.0                 NaN
# 106             1.0   NaN                100.0                 NaN
# 107             1.0   NaN                100.0                 NaN
# 108             1.0   NaN                100.0                 NaN
# 109             1.0   NaN                100.0                 NaN
# 110             1.0   NaN                100.0                 NaN
# 111             1.0   NaN                100.0                 NaN
# 112             1.0   NaN                100.0                 NaN
# 113             1.0   NaN                100.0                 NaN
# 114             1.0   NaN                100.0                 NaN
# 115             1.0   NaN                100.0                 NaN
# 116             1.0   NaN                100.0                 NaN
# 117             1.0   NaN                100.0                 NaN
# 118             1.0   NaN                100.0                 NaN
# 119             1.0   NaN                100.0                 NaN
# 120             1.0   NaN                100.0                 NaN
# 121             1.0   NaN                100.0                 NaN
# 122             1.0   NaN                100.0                 NaN
# 123             1.0   NaN                100.0                 NaN
# 124             1.0   NaN                100.0                 NaN
# 125             1.0   NaN                100.0                 NaN
# 68              1.0   NaN                100.0                 NaN
# 69              1.0   NaN                100.0                 NaN
# 70              1.0   NaN                100.0                 NaN
# 71              1.0   NaN                100.0                 NaN
# 72              1.0   NaN                100.0                 NaN
# 73              1.0   NaN                100.0                 NaN
# 74              1.0   NaN                100.0                 NaN
# 75              1.0   NaN                100.0                 NaN
# 76              1.0   NaN                100.0                 NaN
# 77              1.0   NaN                100.0                 NaN
# 78              1.0   NaN                100.0                 NaN
# 79              1.0   NaN                100.0                 NaN
# 80              1.0   NaN                100.0                 NaN
# 81              1.0   NaN                100.0                 NaN
# 82              1.0   NaN                100.0                 NaN
# 83              1.0   NaN                100.0                 NaN
# 84              1.0   NaN                100.0                 NaN
# 85              1.0   NaN                100.0                 NaN
# 86              1.0   NaN                100.0                 NaN
# 87              1.0   NaN                100.0                 NaN
# 88              1.0   NaN                100.0                 NaN
# 89              1.0   NaN                100.0                 NaN
# 90              1.0   NaN                100.0                 NaN
# 91              1.0   NaN                100.0                 NaN
# 92              1.0   NaN                100.0                 NaN
# 93              1.0   NaN                100.0                 NaN
# 94              1.0   NaN                100.0                 NaN
# 95              1.0   NaN                100.0                 NaN
# 96              1.0   NaN                100.0                 NaN
# 97              1.0   NaN                100.0                 NaN
# 98              1.0   NaN                100.0                 NaN
# 99              1.0   NaN                100.0                 NaN
# 100             1.0   NaN                100.0                 NaN
# 0               1.0   NaN                100.0                 NaN
# 1               1.0   NaN                100.0                 NaN
# 2               1.0   NaN                100.0                 NaN
# 3               1.0   NaN                100.0                 NaN
# 4               1.0   NaN                100.0                 NaN
# 5               1.0   NaN                100.0                 NaN
#
#     reliability_rating                                           filename  \
# 6                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 7                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 8                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 9                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 10                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 11                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 12                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 13                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 14                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 15                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 16                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 17                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 18                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 19                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 20                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 21                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 22                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 23                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 24                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 25                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 26                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 27                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-05...
# 101                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 102                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 103                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 104                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 105                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 106                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 107                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 108                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 109                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 110                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 111                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 112                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 113                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 114                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 115                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 116                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 117                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 118                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 119                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 120                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 121                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 122                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 123                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 124                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 125                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-12...
# 68                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 69                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 70                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 71                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 72                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 73                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 74                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 75                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 76                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 77                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 78                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 79                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 80                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 81                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 82                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 83                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 84                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 85                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 86                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 87                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 88                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 89                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 90                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 91                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 92                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 93                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 94                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 95                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 96                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 97                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 98                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 99                 1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 100                1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-20...
# 0                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-23...
# 1                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-23...
# 2                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-23...
# 3                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-23...
# 4                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-23...
# 5                  1.0  fga-eps-mds-2020_2-Projeto-Kokama-Front-end-23...
#
#                           repository     version
# 6    2020_2-Projeto-Kokama-Front-end  05-04-2021
# 7    2020_2-Projeto-Kokama-Front-end  05-04-2021
# 8    2020_2-Projeto-Kokama-Front-end  05-04-2021
# 9    2020_2-Projeto-Kokama-Front-end  05-04-2021
# 10   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 11   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 12   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 13   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 14   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 15   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 16   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 17   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 18   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 19   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 20   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 21   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 22   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 23   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 24   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 25   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 26   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 27   2020_2-Projeto-Kokama-Front-end  05-04-2021
# 101  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 102  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 103  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 104  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 105  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 106  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 107  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 108  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 109  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 110  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 111  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 112  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 113  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 114  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 115  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 116  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 117  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 118  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 119  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 120  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 121  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 122  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 123  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 124  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 125  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 68   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 69   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 70   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 71   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 72   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 73   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 74   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 75   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 76   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 77   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 78   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 79   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 80   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 81   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 82   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 83   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 84   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 85   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 86   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 87   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 88   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 89   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 90   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 91   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 92   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 93   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 94   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 95   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 96   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 97   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 98   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 99   2020_2-Projeto-Kokama-Front-end  20-05-2021
# 100  2020_2-Projeto-Kokama-Front-end  20-05-2021
# 0    2020_2-Projeto-Kokama-Front-end  23-03-2021
# 1    2020_2-Projeto-Kokama-Front-end  23-03-2021
# 2    2020_2-Projeto-Kokama-Front-end  23-03-2021
# 3    2020_2-Projeto-Kokama-Front-end  23-03-2021
# 4    2020_2-Projeto-Kokama-Front-end  23-03-2021
# 5    2020_2-Projeto-Kokama-Front-end  23-03-2021

# %% [markdown]
# ### Metric calculations

# %% [markdown]
# ##### COMPLEXITY

# %%
def m1(df):
    
    density_non_complex_files = len(df[(df['complexity'].astype(float)/df['functions'].astype(float)) < 10])/len(df)
    
    return density_non_complex_files

# %% [markdown]
# ##### COMMENTS

# %%
def m2(df):
    
    density_comment_files = len(df[(df['comment_lines_density'].astype(float) > 10) & (df['comment_lines_density'].astype(float) < 30)])/len(df)
    
    return density_comment_files

# %% [markdown]
# ##### DUPLICATIONS

# %%
def m3(df):
    
    duplication = len(df[(df['duplicated_lines_density'].astype(float) < 5)])/len(df)
    
    return duplication

# %% [markdown]
# ### Calculate m1, m2 and m3 for each repository

# %%
def create_metrics_df(df):
    
    version_vec = df['version'].unique()
    
    m1_list = []
    m2_list = []
    m3_list = []
    repository_list = []
    version_list = []
    
    metrics_df = pd.DataFrame()
    
    for version in version_vec:

        version_df = df[df['version'] == version]

        m1_list.append(m1(version_df))
        m2_list.append(m2(version_df))
        m3_list.append(m3(version_df))
        repository_list.append(version_df['repository'].iloc[0])
        version_list.append(version)
        
    metrics_df = pd.DataFrame({'m1': m1_list,
                               'm2': m2_list,
                               'm3': m3_list,
                               'repository': repository_list, 
                               'version': version_list})
        
    return metrics_df

# %%
repository_metrics = {}

for repository, repo_df in repository_dataframes.items():   
    metrics_df = create_metrics_df(repo_df)
    metrics_df.name = f"{repository}"
    repository_metrics[f"{repository}"] = metrics_df

# %% [markdown]
# ### Data visualization
#
# - You must do this for each of your repositories

# %%
repository_metrics
# Out:
# {'2020_2-Projeto-Kokama-Traducao':          m1        m2   m3                      repository     version
#  0  0.190476  0.095238  1.0  2020_2-Projeto-Kokama-Traducao  05-04-2021
#  1  0.285714  0.142857  1.0  2020_2-Projeto-Kokama-Traducao  06-04-2021
#  2  0.173913  0.086957  1.0  2020_2-Projeto-Kokama-Traducao  23-03-2021,
#  '2020_2-Projeto-Kokama-Usuario':     m1   m2   m3                     repository     version
#  0  0.0  0.0  1.0  2020_2-Projeto-Kokama-Usuario  17-04-2021,
#  '2020_2-Projeto-Kokama-Ensino':          m1        m2   m3                    repository     version
#  0  0.230769  0.076923  1.0  2020_2-Projeto-Kokama-Ensino  14-04-2021,
#  '2020_2-Projeto-Kokama-Front-end':          m1        m2   m3                       repository     version
#  0  0.545455  0.045455  1.0  2020_2-Projeto-Kokama-Front-end  05-04-2021
#  1  0.560000  0.040000  1.0  2020_2-Projeto-Kokama-Front-end  12-05-2021
#  2  0.515152  0.030303  1.0  2020_2-Projeto-Kokama-Front-end  20-05-2021
#  3  0.500000  0.000000  1.0  2020_2-Projeto-Kokama-Front-end  23-03-2021}

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMPLEXITY")
    plt.plot(metrics_df['m1'], linewidth=3, marker='o', markersize=10)

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMMENTS")
    plt.plot(metrics_df['m2'], linewidth=3, marker='o', markersize=10)

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:DUPLICATIONS")
    plt.plot(metrics_df['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ### Sub characteristic aggregation

# %%
psc1 = 1
pm1 = 0.33
pm2 = 0.33
pm3 = 0.33

for repository, metrics_df in repository_metrics.items(): 
    metrics_df['asc1'] = ((metrics_df['m1']*pm1)+(metrics_df['m2']*pm2)+(metrics_df['m3']*pm3))*psc1

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:asc1")
    plt.plot(metrics_df['asc1'], linewidth=3, marker='o', markersize=10)

# %%
all_metrics_df = pd.DataFrame()

for repository, metrics_df in repository_metrics.items():
    all_metrics_df = pd.concat([all_metrics_df, metrics_df], ignore_index=True)

all_metrics_df['ac1'] = all_metrics_df['asc1'] * 1
all_metrics_df['total'] = all_metrics_df['asc1'] * 1

# %%
all_metrics_df
# Out:
#          m1        m2   m3                       repository     version  \
# 0  0.190476  0.095238  1.0   2020_2-Projeto-Kokama-Traducao  05-04-2021
# 1  0.285714  0.142857  1.0   2020_2-Projeto-Kokama-Traducao  06-04-2021
# 2  0.173913  0.086957  1.0   2020_2-Projeto-Kokama-Traducao  23-03-2021
# 3  0.000000  0.000000  1.0    2020_2-Projeto-Kokama-Usuario  17-04-2021
# 4  0.230769  0.076923  1.0     2020_2-Projeto-Kokama-Ensino  14-04-2021
# 5  0.545455  0.045455  1.0  2020_2-Projeto-Kokama-Front-end  05-04-2021
# 6  0.560000  0.040000  1.0  2020_2-Projeto-Kokama-Front-end  12-05-2021
# 7  0.515152  0.030303  1.0  2020_2-Projeto-Kokama-Front-end  20-05-2021
# 8  0.500000  0.000000  1.0  2020_2-Projeto-Kokama-Front-end  23-03-2021
#
#        asc1       ac1     total
# 0  0.424286  0.424286  0.424286
# 1  0.471429  0.471429  0.471429
# 2  0.416087  0.416087  0.416087
# 3  0.330000  0.330000  0.330000
# 4  0.431538  0.431538  0.431538
# 5  0.525000  0.525000  0.525000
# 6  0.528000  0.528000  0.528000
# 7  0.510000  0.510000  0.510000
# 8  0.495000  0.495000  0.495000

# %%
all_metrics_df.to_excel('data/metrics_df.xlsx', index = False)
